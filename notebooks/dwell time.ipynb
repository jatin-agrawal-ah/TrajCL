# %%
# %sql
select * from main_prod.ml_data.cm_work_dwell_time_v3_2 where userid = 23122754

# %%
userid = 23122754
calc_date = '2025-10-01'
query = """
select * from main_prod.ml_data.cm_work_dwell_time_v3_2 where userid = {} and calc_date = '{}'
""".format(userid, calc_date)
df = spark.sql(query)
df_pd = df.toPandas()
if len(df_pd) > 0:
    timespend_work_hours = df_pd['timespend_work_hours'].iloc[0]

print(timespend_work_hours)

# %%
query

# %%
# %sql
select postedon, userid, amount, categories, merchantname, website, description from main_prod.bank_transactions.bank_transactions_v2 where userid = 23122754 and amount<0 order by postedon desc
