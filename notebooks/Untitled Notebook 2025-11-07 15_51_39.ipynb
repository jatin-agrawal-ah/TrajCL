# %%
# %sql
select * from main_prod.datascience_scratchpad.earnings_if_v6_amt_dev_test_100pct

# %%
query = """
select userid, paydate from main_prod.datascience_scratchpad.earnings_if_v6_amt_dev_test_100pct where pck_amt > 0 and prev_pck_amt > 0
"""
earnings_df = spark.sql(query).distinct()

# %%
display(earnings_df)

# %%
earnings_df.count()

# %%
earnings_df.select('userid').distinct().count()

# %%
my_test = spark.read.parquet("/Volumes/main_prod/datascience_scratchpad/jatin/pck_forecast/datasets/v3_1/test_df_v3")
display(my_test)

# %%
my_test.count()

# %%
my_test.select('userid').distinct().count()

# %%
query = """
select df1.* from main_prod.datascience_scratchpad.earnings_if_v6_amt_dev_test_100pct df1
inner join main_prod.datascience_scratchpad.earnings_test_amounts_v3 df2
on df1.userid = df2.userid
"""
joined = spark.sql(query)
display(joined)

# %%
joined.select('userid','paydate').distinct().count()

# %%
joined.select('userid').distinct().count()

# %%
joined.write.mode('overwrite').saveAsTable('main_prod.datascience_scratchpad.earnings_if_v6_amt_dev_test_100pct_filtered')
